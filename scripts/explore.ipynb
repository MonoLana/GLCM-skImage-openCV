# %%
import pandas as pd

# %%
filepath = "C:/Users/naufa/Documents/mlInit/rice-GLCM/data/processed/rice-extract.csv"
df = pd.read_csv(filepath)

# %%
df
# Out:
#        Unnamed: 0  Arborio_contrast  Arborio_homogeneity  Arborio_energy  \
# 0               0         62.881317             0.905826        0.677839
# 1               1        126.453976             0.891246        0.664493
# 2               2         68.151165             0.895647        0.666617
# 3               3        121.589590             0.876915        0.647958
# 4               4         70.670908             0.889040        0.670622
# ...           ...               ...                  ...             ...
# 14995       14995         96.118072             0.885122        0.659738
# 14996       14996        106.040064             0.879986        0.650306
# 14997       14997        111.035470             0.882582        0.649654
# 14998       14998         74.443277             0.901690        0.667543
# 14999       14999        107.722378             0.900978        0.674760
#
#        Arborio_correlation  Basmati_contrast  Basmati_homogeneity  \
# ...
